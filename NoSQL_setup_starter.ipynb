),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205752'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205753'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205757'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220575a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220575c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220575d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220575e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220575f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205760'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205761'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205763'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205765'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205766'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205769'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220576a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220576b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220576c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220576e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205771'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205772'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205774'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205775'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205776'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205777'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205778'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205779'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220577b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220577f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205780'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d92205789'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220578a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220578b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6132f4ad5d9220578c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220578d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220578f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205798'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205799'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220579b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220579c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220579f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057a5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057c5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057d4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057d8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057db'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d922057e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e41'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e44'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e45'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e5b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e5e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e62'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e68'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e6d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e70'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e78'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e82'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e84'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e89'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e95'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e9b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205e9c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ea6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ea8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ebd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ec0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ec1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ec2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ec6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ec9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ecc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ed7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205edb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205edf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ee6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205eee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ef6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f08'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f16'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f23'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f24'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f2c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f31'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f32'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f40'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f41'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f46'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f4d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f57'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f75'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f81'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f83'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f86'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f87'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f8b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f8c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f98'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205f9a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fa3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fa4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fa5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fa7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fa8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fa9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fb2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fb3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fb5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fb6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fb8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fb9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fbc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fbd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fbe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fc2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fc5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fcb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fcc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fd9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fdc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fdd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fe0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fe4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fe6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fe9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205feb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205fee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ff3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ff4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ff7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92205ff8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206005'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206006'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206008'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220600c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220600e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220600f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206012'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206014'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206015'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206016'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206017'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206019'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220601d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220601f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206022'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206024'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206027'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206028'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220602b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220602f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206032'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206038'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220603a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220603e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206041'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206042'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206043'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206045'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206048'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220604a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220604d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206050'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206051'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206052'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206053'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206056'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206057'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d92206058'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220605c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('65af4c6232f4ad5d9220605d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  ...]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query = {'BusinessName': 'Penang Flavours'}
field = {'$set': {'BusinessTypeID': 1}}
result = establishments.update_one(query,field)

# %%
# Confirm that the new restaurant was updated
pprint(list(establishments.find(query)))
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65af4c73b0d0437d2d90991a'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName' : 'Dover'}
print(establishments.count_documents(query))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName' : 'Dover'}
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
print(establishments.count_documents(query))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65af4c6132f4ad5d922054e6'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude

establishments.update_many({},[{'$set':{'geocode.longitude':{'$toDouble':'$geocode.longitude'}}}])

# %%
# Change the data type from String to Decimal for longitude and latitude

establishments.update_many({}, [{'$set':{'geocode.latitude':{'$toDouble':'$geocode.latitude'}}}])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{'$set': {'RatingValue':{'$toInt':'$RatingValue'}}}])

# %%
# Check that the coordinates and rating value are now numbers
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65af4c6132f4ad5d922054e6'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
